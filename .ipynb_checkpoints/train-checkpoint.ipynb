# %% [markdown]
# # Loading data

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/mawi/.local/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.21.0 in /home/mawi/.local/lib/python3.10/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: pytz>=2020.1 in /home/mawi/.local/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mawi/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/mawi/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/mawi/.local/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: six>=1.5 in /home/mawi/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/mawi/.local/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: matplotlib>=3.1 in /home/mawi/.local/lib/python3.10/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.25 in /home/mawi/.local/lib/python3.10/site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/mawi/.local/lib/python3.10/site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (4.37.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.1->seaborn) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mawi/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/mawi/.local/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /home/mawi/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/mawi/.local/lib/python3.10/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/mawi/.local/lib/python3.10/site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/mawi/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mawi/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/mawi/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/mawi/.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.23.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# using a style for the plots
sns.set(rc={'axes.facecolor':"#EBE0BA",
            "figure.facecolor":"#E0D3AF",
            "grid.color":"#E0D3AF",
            "axes.edgecolor":"#424949",
            "axes.labelcolor":"#424949",
            "text.color":"#424949" # color for headlines and sub headlines
           }) 
#opening the files
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.pairplot(train, hue="Survived")

# %% [markdown]
# # Tratamiento de datos

# %%
train.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
test.isnull().mean()
# we only have to treat sex since is the only missing value that is going to be used in this model, fare is not relevan
# Out:
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.205742
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.002392
# Cabin          0.782297
# Embarked       0.000000
# dtype: float64

# %% [markdown]
# ## Treatment for null ages

# %%
print(train[(train["Pclass"]==1) & (train["Sex"]=="female")]["Age"].median())
print(train[(train["Pclass"]==1) & (train["Sex"]=="male")]["Age"].median())
print(train[(train["Pclass"]==2) & (train["Sex"]=="female")]["Age"].median())
print(train[(train["Pclass"]==2) & (train["Sex"]=="male")]["Age"].median())
print(train[(train["Pclass"]==3) & (train["Sex"]=="female")]["Age"].median())
print(train[(train["Pclass"]==3) & (train["Sex"]=="male")]["Age"].median())
# Out:
# 35.0
# 40.0
# 28.0
# 30.0
# 21.5
# 25.0

# %%
from itertools import product
l1, l2 = [1,2,3], ["female","male"]
for c,s in product(l1,l2):
    #for train
    msk_train = (train["Pclass"]==c) & (train["Sex"]==s)
    train.loc[msk_train,"Age"] = train[msk_train]["Age"].fillna(train[msk_train]["Age"].median())
    #for test
    msk_test = (test["Pclass"]==c) & (test["Sex"]==s)
    test.loc[msk_test,"Age"] = test[msk_test]["Age"].fillna(test[msk_test]["Age"].median())

# %% [markdown]
# ## Treatment for null embarked

# %% [markdown]
# since there are only two null values in embarked col, we replace it with a fixed value

# %%
train.loc[train["Embarked"].isna(),"Embarked"] = "S"

# %% [markdown]
# # Finding some relevant information

# %%
scr_df = train.copy()
ts_df = test.copy()

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  24.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  24.0      0      0              359309    8.0500   NaN        S
# 417    male  24.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# Changing categorical data to numerical for manipulation

# %%
sex_dict = {'male': 0, 'female': 1}
embarked_dict = {'S': 1, 'C': 2, 'Q': 3}
# for train
def sx_embarked_to_cat(df):
    df = df[df['Embarked'].notnull()].copy()
    df.loc[:, 'Sex'] = df.loc[:,'Sex'].map(lambda x: sex_dict[x])
    df.loc[:, 'Embarked'] = df.loc[:, 'Embarked'].map(lambda x: embarked_dict[x])
    return df
# for test 
scr_df = sx_embarked_to_cat(scr_df)
ts_df = sx_embarked_to_cat(ts_df)

# %% [markdown]
# Getting  the correlation of the variables to find valueable information

# %%
corr = scr_df.corr()
f, ax = plt.subplots(figsize=(25, 15))
# change x- and y-label size
ax.tick_params(axis='both', which='major', labelsize=15)
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, mask=mask, cmap="coolwarm", center=0, square=True, linewidths=1, linecolor="#424949", annot=True, 
                cbar_kws={"shrink": 0.6}).set_title('Pairwise correlation', fontsize="28");

# %% [markdown]
# Getting relation between sex and class survival probability

# %%
sex_class_prob_dict = {}
#  1 = female, 0 = male
for n in [0, 1]:
    for m in [1,2,3]:
        df = scr_df[(scr_df['Pclass'] == m) & (scr_df['Sex'] == n)].copy()
        gender = "hombre" if n == 0 else "mujer"
        sex_class_prob_dict[gender + f", clase: {str(m)}"] = round(len(df[df['Survived'] == 1]) / len(df['Survived']),2)

# %%
df = pd.DataFrame.from_dict(sex_class_prob_dict, orient='index').rename(columns={0: "Probabilidad"})
df['clase'] = df.index
fg = sns.catplot(data=df, kind="bar", y="clase", x="Probabilidad", height=5, color="#97A7B2",  aspect=3.9, linewidth = 3, ec="#424949")
fg.set_xticklabels(fontsize=15)
fg.set_yticklabels(fontsize=15)
fg.fig.subplots_adjust(top=0.8)
fg.fig.suptitle("Probabilidad de supervivencia", fontsize="28")
# Out:
# Text(0.5, 0.98, 'Probabilidad de supervivencia')

# %% [markdown]
# # Choosing variables

# %% [markdown]
# > Since we saw a high relationship between gender, class an survival we decided to included in our model, but no more numerical data has a strong relation between survival other than fare, so we decide to search more on the categorical data.
#
# > We choose to search more on the ticket to see if we could get more information on that, since the cabin variable has a 77% porcent of null values and could be biased to threat it

# %%
scr_df['Ticket'].value_counts().nlargest(5)
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
# Name: Ticket, dtype: int64

# %%
scr_df[scr_df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name  Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    0
# 180          181         0       3       Sage, Miss. Constance Gladys    1
# 201          202         0       3                Sage, Mr. Frederick    0
# 324          325         0       3           Sage, Mr. George John Jr    0
# 792          793         0       3            Sage, Miss. Stella Anna    1
# 846          847         0       3           Sage, Mr. Douglas Bullen    0
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"    1
#
#       Age  SibSp  Parch    Ticket   Fare Cabin  Embarked
# 159  25.0      8      2  CA. 2343  69.55   NaN         1
# 180  21.5      8      2  CA. 2343  69.55   NaN         1
# 201  25.0      8      2  CA. 2343  69.55   NaN         1
# 324  25.0      8      2  CA. 2343  69.55   NaN         1
# 792  21.5      8      2  CA. 2343  69.55   NaN         1
# 846  25.0      8      2  CA. 2343  69.55   NaN         1
# 863  21.5      8      2  CA. 2343  69.55   NaN         1

# %% [markdown]
# > As we said before, the fare was the numerical data with strong relation between survival, but, since the tickets of a whole family has the same fare, we believe that this data could be very biased

# %%
tmp_df = scr_df['Ticket'].str.split(' ', 1, expand=True).copy()

tmp_df[1][tmp_df[1].isnull()] = tmp_df[0]
tmp_df[0][tmp_df[1] == tmp_df[0]] = 'no_prefix' 

scr_df[['Ticket_prefix', 'Ticket_number']]= tmp_df

# %%
scr_df['Ticket_prefix'].value_counts(100)
# Out:
# no_prefix     0.746352
# PC            0.067340
# C.A.          0.030303
# STON/O        0.013468
# A/5           0.011223
# W./C.         0.010101
# CA.           0.008979
# SOTON/O.Q.    0.008979
# SOTON/OQ      0.007856
# A/5.          0.007856
# CA            0.006734
# STON/O2.      0.006734
# C             0.005612
# F.C.C.        0.005612
# S.O.C.        0.005612
# SC/PARIS      0.005612
# SC/Paris      0.004489
# S.O./P.P.     0.003367
# PP            0.003367
# A/4.          0.003367
# A/4           0.003367
# SC/AH         0.003367
# A./5.         0.002245
# SOTON/O2      0.002245
# A.5.          0.002245
# WE/P          0.002245
# S.C./PARIS    0.002245
# P/PP          0.002245
# F.C.          0.001122
# SC            0.001122
# S.W./PP       0.001122
# A/S           0.001122
# Fa            0.001122
# SCO/W         0.001122
# SW/PP         0.001122
# W/C           0.001122
# S.C./A.4.     0.001122
# S.O.P.        0.001122
# A4.           0.001122
# W.E.P.        0.001122
# SO/C          0.001122
# S.P.          0.001122
# C.A./SOTON    0.001122
# Name: Ticket_prefix, dtype: float64

# %% [markdown]
# # Training

# %% [markdown]
# LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
features = ['Sex','Pclass','SibSp','Embarked','Parch']
x_train=scr_df[features]
y_train=train['Survived']
lg=LogisticRegression()
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
lg_predicted = lg.predict(x_train)
data = pd.concat([pd.DataFrame(lg_predicted), y_train])

df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
cf = confusion_matrix(lg_predicted, y_train)
sns.heatmap(cf, annot=True, fmt="g")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 6>()
#       3 data = pd.concat([pd.DataFrame(lg_predicted), y_train])
#       5 df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
# ----> 6 cf = confusion_matrix(lg_predicted, y_train, fmt="g")
#       7 sns.heatmap(cf, annot=True)
#
# TypeError: confusion_matrix() got an unexpected keyword argument 'fmt'

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Testing
from sklearn.metrics import accuracy_score


rf_predicted = rf.predict(x_train)

lg_scr = accuracy_score(lg_predicted, y_train)
rf_scr = accuracy_score(rf_predicted, y_train)
print("Logistic Regresion:", lg_scr, "Random Forest:", rf_scr)
# Out:
# Logistic Regresion: 0.8024691358024691 Random Forest: 0.8372615039281706

# %%
# Saving models and usefull info
import pickle
pickle.dump(lg,open("lg.model", "wb" ))
pickle.dump(lg,open("rf.model","wb"))

# %% [markdown]
# # Saving submision for kaggle

# %%
ts_df
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
#       Age  SibSp  Parch              Ticket      Fare Cabin  Embarked
# 0    34.5      0      0              330911    7.8292   NaN         3
# 1    47.0      1      0              363272    7.0000   NaN         1
# 2    62.0      0      0              240276    9.6875   NaN         3
# 3    27.0      0      0              315154    8.6625   NaN         1
# 4    22.0      1      1             3101298   12.2875   NaN         1
# ..    ...    ...    ...                 ...       ...   ...       ...
# 413  24.0      0      0           A.5. 3236    8.0500   NaN         1
# 414  39.0      0      0            PC 17758  108.9000  C105         2
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN         1
# 416  24.0      0      0              359309    8.0500   NaN         1
# 417  24.0      1      1                2668   22.3583   NaN         2
#
# [418 rows x 11 columns]

# %%
x = ts_df[features]
y = rf.predict(x)

prediction=pd.DataFrame(y, columns=['Survived'])
submission_last=pd.concat([ts_df[['PassengerId']],prediction],axis=1)
submission_last.to_csv('random_forest.csv',index=False)

y = lg.predict(x)

prediction=pd.DataFrame(y, columns=['Survived'])
submission_last=pd.concat([ts_df[['PassengerId']],prediction],axis=1)
submission_last.to_csv('logistic_regresion.csv',index=False)
